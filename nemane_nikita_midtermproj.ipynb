# %%
import pandas as pd;
import numpy as np;

# %%
data1=[]
order_of_elements = []
dictionary={}

# %%
def load_data_set():
    print("Please enter which data set you need \n1)Amazon \n2)BestBuy \n3)Nike \n4)Data1")
    while True:
        choice_of_data = input()
        if choice_of_data == "1":
            path_to_data = "Amazon.csv"
            print("User chose Amazon dataset")
            break
        elif (choice_of_data =="2"):
            path_to_data ="Bestbuy.csv"
            print("User chose BestBuy dataset")
            break
        elif (choice_of_data =="3"):
            path_to_data ="Nike.csv"
            print("User chose Nike dataset")
            break
        elif (choice_of_data =="4"):
            path_to_data ="Data1.csv"
            print("User chose Data1 dataset")
            break
        else:
            print("Please enter the right input between 1 to 4")
    return path_to_data

# %%
# This function receives path to data and order of items
def load_data(data_path,order):
#     Loads the data
    Transactions=[] #list to append transactions
    path = pd.read_csv(data_path)
    transaction_data = path.Transactions
#     print("td",transaction_data)
    for t in transaction_data:
        comma_separated = list(t.strip().split(',')) #will get list of items
        unique_data = list(np.unique(comma_separated)) #unique is used to remove repetition
        unique_data.sort(key=lambda x: order.index(x)) #sort according to lexical order
        Transactions.append(unique_data) #Append into the transaction list
#     print("Transactions",Transactions)
    return Transactions

# %%
#load the data and return order of data
def single_element():
    path = pd.read_csv(data_path)
    records = path.Transactions
    for i in records:
        comma_separated = i.split(",")
        for j in comma_separated:
            data1.append(j)
    for k in data1:
        count = 0
        for l in data1:
            if(k==l):
                count+=1
        dictionary.update({k:count})
    for i in dictionary.keys():
        order_of_elements.append(i)
#     print("order of elements",order_of_elements)
    return order_of_elements

# %%
#This function goes over the transactions and count the number of occurences
# Using python sets operation to check if the itemset is subset of the set
# and if it is then incrementing the count
def occurence_count(items, Transactions):
    count =0
    for i in range(len(Transactions)):
        if set(items).issubset(set(Transactions[i])):
            count+=1
    return count

# %%
#This function joins two sets, it first sorts itemsets according to their order
#Checks if they are joinable, means all the items within the sorted itemsets are same except the last one
#and in the last one the one belonging to second itemset must be greater than the last one in the 1st itemset
def combination_two_sets(set1,set2,order):
    set1.sort(key=lambda x: order.index(x))
    set2.sort(key=lambda x: order.index(x))
    for i in range(len(set1)-1):
        if set1[i]!=set2[i]:
            return []
    if order.index(set1[-1])< order.index(set2[-1]):  #last item of each itemset
        return set1+[set2[-1]]
#     print("->",[])
    return [] #if the condition does not satisfies then return empty list

# %%
#This function joins 2 itemsets
#It will look for each of the itemset within set of itemsets
#it will check if combination_of_two_sets returns empty list and then append in the combination set
def combination_sets(sets,order):
    C_S = []
    for i in range(len(sets)):
        for j in range(i+1,len(sets)):
            it_out = combination_two_sets(sets[i],sets[j],order)
            if len(it_out)>0:
                C_S.append(it_out)
#     print("C_S",C_S)
    return C_S

# %%
#This function will return List of frequent itemsets, List of their support counts and List of newly discarded items
#It will check the length of discarded items list if it is greater than 0 then it will check
#whether they contain any subset of itemsets that was previously discarded
#else it will call occurence_count function to count their frequency
#check if it is greater than threshold support
#if greater then append to the List of frequent items.
#else append to the list of discarded items
def get_frequent_items(itemsets, Transactions, support, prev_discarded):
    L=[]
    supp_count=[]
    new_discarded =[]    
    k = len(prev_discarded.keys())
    for s in range(len(itemsets)):
        discarded_before = False
        if k > 0:
            for it in prev_discarded[k]:
                if set(it).issubset(set(itemsets[s])):
                    discarded_before = True
                    break
        if not discarded_before:
            count = occurence_count(itemsets[s],Transactions)
            if count/len(Transactions) >= support:
                L.append(itemsets[s])
                supp_count.append(count)
            else:
                new_discarded.append(itemsets[s])
    print('List of Frequent Items-',L)
    print("Support Count-",supp_count)
    print("New Discarded Items\b",new_discarded)
    return L, supp_count, new_discarded

# %%
from itertools import combinations, chain
#returns all the subsets
#using itertools library
#combinations returns all the posible combinations of specific size
#chain will put iterables given by combination in just one iterable
#combinations of s on size r from 1 to len(itemset)+1
def powerset(s):
    return list(chain.from_iterable(combinations(s,r) for r in range(1, len(s)+1)))

def write_rules(X,X_S,S,conf,sup,number_of_trans):
    out_rules = ""
    out_rules+= "\nFreq. Itemsets: {} \n".format(X)
    out_rules+= "    Rule: {} -> {} \n".format(list(S),list(X_S))
    out_rules+="   Confidance: {0:2.3f} ".format(conf) #string formatting rounding off the decimal places to 3
    out_rules+="   Support: {0:2.3f} ".format(sup/number_of_trans)
    return out_rules

# %%
data_path = load_data_set()
order = single_element()
Transactions = load_data(data_path,order)
while True:
    try:
        support= float(input("Enter support in percent:(1 to 100)"))
        if support<1 or support>100:
            raise ValueError
        break
    except ValueError:
        print("Invalid support value.The number must be in the range of 1-100")
while True:
    try:
        confidence= float(input("Enter confidence in percent:(1 to 100)"))
        if confidence<1 or confidence>100:
            raise ValueError
        break
    except ValueError:
        print("Invalid support value.The number must be in the range of 1-100")

min_support = support/100
min_conf = confidence/100

number_of_trans = len(Transactions)
Transactions
#Initialization
C={}  #set of candidates as a dictionary where the keys are going to be the iterations
L={}
itemset_size = 1
Discarded = {itemset_size:[]}
C.update({itemset_size : [[f] for f in order]}) #all the candidates of itemset of size 1
C
# Out:
# Please enter which data set you need
# 1)Amazon
# 2)BestBuy
# 3)Nike
# 4)Data1
# 2
# User chose BestBuy dataset
# Enter support in percent:(1 to 100)20
# Enter confidence in percent:(1 to 100)30
# {1: [['Desk Top'],
#   [' Printer'],
#   [' Flash Drive'],
#   [' Microsoft Office'],
#   [' Speakers'],
#   [' Anti-Virus '],
#   ['Lab Top'],
#   [' Lab Top Case'],
#   [' Anti-Virus'],
#   [' External Hard-Drive '],
#   [' External Hard-Drive'],
#   [' Lab Top Case '],
#   [' Microsoft Office '],
#   ['Digital Camera '],
#   [' Lab Top'],
#   [' Desk Top'],
#   [' Speakers '],
#   ['Printer'],
#   ['Digital Camera']]}

# %%
#Create L1 dictionary similar to C but containning only frequent items
supp_count_L={}
f,sup, new_discarded= get_frequent_items(C[itemset_size],Transactions, min_support, Discarded)
Discarded.update({itemset_size :new_discarded})#update variables with just generated outputs
L.update({itemset_size:f})
supp_count_L.update({itemset_size: sup})
# Out:
# List of Frequent Items- [[' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive'], ['Digital Camera '], [' Lab Top']]
# Support Count- [9, 13, 11, 11, 7, 14, 14, 9, 8, 5]
#  [['Desk Top'], [' Anti-Virus '], [' External Hard-Drive '], [' Lab Top Case '], [' Microsoft Office '], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera']]

# %%
#Function to print the table
def print_table(T,supp_count):
    print("Itemset  | Frequency")
    for k in range(len(T)):
        print("{}   :   {}".format(T[k],supp_count[k]))
    print("\n\n")
print_table(L[1], supp_count_L[1]) #to print 1st iteration
# Out:
# Itemset  | Frequency
# [' Printer']   :   9
# [' Flash Drive']   :   13
# [' Microsoft Office']   :   11
# [' Speakers']   :   11
# ['Lab Top']   :   7
# [' Lab Top Case']   :   14
# [' Anti-Virus']   :   14
# [' External Hard-Drive']   :   9
# ['Digital Camera ']   :   8
# [' Lab Top']   :   5

# %%
#now we are going to implement the main loop of the algorithm.
#we need to generate candidates on each iteration set of itemset of size k
#after that we need to generate frequent itemsets
#to generate the c[k], we are going to need the join step from L[k-1]
#after that we are able to generate L[k] the frequent itemsets
#if size of L[k]>1 then algo works else the set is empty the algo stops
k=itemset_size+1
convergence = False
while not convergence:
    C.update({ k : combination_sets(L[k-1],order)})
    print(C)
    print("\nTable of Frequent itemsets C{}: \n".format(k))
    print_table(C[k],[occurence_count(it,Transactions) for it in C[k]])
    f,sup,new_discarded = get_frequent_items(C[k],Transactions,min_support,Discarded)
    Discarded.update({k:new_discarded})
    L.update({k:f})
    supp_count_L.update({k:sup})
    if len(L[k])==0:
        convergence=True
    else:
        print("\nTable of selected Frequent itemsets L{} \n".format(k))
        print_table(L[k],supp_count_L[k])
    k+=1
# Out:
# {1: [['Desk Top'], [' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], [' Anti-Virus '], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive '], [' External Hard-Drive'], [' Lab Top Case '], [' Microsoft Office '], ['Digital Camera '], [' Lab Top'], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera']], 2: [[' Printer', ' Flash Drive'], [' Printer', ' Microsoft Office'], [' Printer', ' Speakers'], [' Printer', 'Lab Top'], [' Printer', ' Lab Top Case'], [' Printer', ' Anti-Virus'], [' Printer', ' External Hard-Drive'], [' Printer', 'Digital Camera '], [' Printer', ' Lab Top'], [' Flash Drive', ' Microsoft Office'], [' Flash Drive', ' Speakers'], [' Flash Drive', 'Lab Top'], [' Flash Drive', ' Lab Top Case'], [' Flash Drive', ' Anti-Virus'], [' Flash Drive', ' External Hard-Drive'], [' Flash Drive', 'Digital Camera '], [' Flash Drive', ' Lab Top'], [' Microsoft Office', ' Speakers'], [' Microsoft Office', 'Lab Top'], [' Microsoft Office', ' Lab Top Case'], [' Microsoft Office', ' Anti-Virus'], [' Microsoft Office', ' External Hard-Drive'], [' Microsoft Office', 'Digital Camera '], [' Microsoft Office', ' Lab Top'], [' Speakers', 'Lab Top'], [' Speakers', ' Lab Top Case'], [' Speakers', ' Anti-Virus'], [' Speakers', ' External Hard-Drive'], [' Speakers', 'Digital Camera '], [' Speakers', ' Lab Top'], ['Lab Top', ' Lab Top Case'], ['Lab Top', ' Anti-Virus'], ['Lab Top', ' External Hard-Drive'], ['Lab Top', 'Digital Camera '], ['Lab Top', ' Lab Top'], [' Lab Top Case', ' Anti-Virus'], [' Lab Top Case', ' External Hard-Drive'], [' Lab Top Case', 'Digital Camera '], [' Lab Top Case', ' Lab Top'], [' Anti-Virus', ' External Hard-Drive'], [' Anti-Virus', 'Digital Camera '], [' Anti-Virus', ' Lab Top'], [' External Hard-Drive', 'Digital Camera '], [' External Hard-Drive', ' Lab Top'], ['Digital Camera ', ' Lab Top']]}
#
# Table of Frequent itemsets C2:
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive']   :   9
# [' Printer', ' Microsoft Office']   :   8
# [' Printer', ' Speakers']   :   4
# [' Printer', 'Lab Top']   :   3
# [' Printer', ' Lab Top Case']   :   5
# [' Printer', ' Anti-Virus']   :   6
# [' Printer', ' External Hard-Drive']   :   4
# [' Printer', 'Digital Camera ']   :   3
# [' Printer', ' Lab Top']   :   2
# [' Flash Drive', ' Microsoft Office']   :   11
# [' Flash Drive', ' Speakers']   :   6
# [' Flash Drive', 'Lab Top']   :   5
# [' Flash Drive', ' Lab Top Case']   :   9
# [' Flash Drive', ' Anti-Virus']   :   10
# [' Flash Drive', ' External Hard-Drive']   :   6
# [' Flash Drive', 'Digital Camera ']   :   3
# [' Flash Drive', ' Lab Top']   :   2
# [' Microsoft Office', ' Speakers']   :   6
# [' Microsoft Office', 'Lab Top']   :   3
# [' Microsoft Office', ' Lab Top Case']   :   7
# [' Microsoft Office', ' Anti-Virus']   :   8
# [' Microsoft Office', ' External Hard-Drive']   :   5
# [' Microsoft Office', 'Digital Camera ']   :   3
# [' Microsoft Office', ' Lab Top']   :   2
# [' Speakers', 'Lab Top']   :   1
# [' Speakers', ' Lab Top Case']   :   9
# [' Speakers', ' Anti-Virus']   :   9
# [' Speakers', ' External Hard-Drive']   :   6
# [' Speakers', 'Digital Camera ']   :   6
# [' Speakers', ' Lab Top']   :   4
# ['Lab Top', ' Lab Top Case']   :   5
# ['Lab Top', ' Anti-Virus']   :   6
# ['Lab Top', ' External Hard-Drive']   :   4
# ['Lab Top', 'Digital Camera ']   :   0
# ['Lab Top', ' Lab Top']   :   0
# [' Lab Top Case', ' Anti-Virus']   :   12
# [' Lab Top Case', ' External Hard-Drive']   :   8
# [' Lab Top Case', 'Digital Camera ']   :   6
# [' Lab Top Case', ' Lab Top']   :   5
# [' Anti-Virus', ' External Hard-Drive']   :   9
# [' Anti-Virus', 'Digital Camera ']   :   4
# [' Anti-Virus', ' Lab Top']   :   4
# [' External Hard-Drive', 'Digital Camera ']   :   2
# [' External Hard-Drive', ' Lab Top']   :   2
# ['Digital Camera ', ' Lab Top']   :   5
#
#
#
# List of Frequent Items- [[' Printer', ' Flash Drive'], [' Printer', ' Microsoft Office'], [' Printer', ' Speakers'], [' Printer', ' Lab Top Case'], [' Printer', ' Anti-Virus'], [' Printer', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office'], [' Flash Drive', ' Speakers'], [' Flash Drive', 'Lab Top'], [' Flash Drive', ' Lab Top Case'], [' Flash Drive', ' Anti-Virus'], [' Flash Drive', ' External Hard-Drive'], [' Microsoft Office', ' Speakers'], [' Microsoft Office', ' Lab Top Case'], [' Microsoft Office', ' Anti-Virus'], [' Microsoft Office', ' External Hard-Drive'], [' Speakers', ' Lab Top Case'], [' Speakers', ' Anti-Virus'], [' Speakers', ' External Hard-Drive'], [' Speakers', 'Digital Camera '], [' Speakers', ' Lab Top'], ['Lab Top', ' Lab Top Case'], ['Lab Top', ' Anti-Virus'], ['Lab Top', ' External Hard-Drive'], [' Lab Top Case', ' Anti-Virus'], [' Lab Top Case', ' External Hard-Drive'], [' Lab Top Case', 'Digital Camera '], [' Lab Top Case', ' Lab Top'], [' Anti-Virus', ' External Hard-Drive'], [' Anti-Virus', 'Digital Camera '], [' Anti-Virus', ' Lab Top'], ['Digital Camera ', ' Lab Top']]
# Support Count- [9, 8, 4, 5, 6, 4, 11, 6, 5, 9, 10, 6, 6, 7, 8, 5, 9, 9, 6, 6, 4, 5, 6, 4, 12, 8, 6, 5, 9, 4, 4, 5]
#  [[' Printer', 'Lab Top'], [' Printer', 'Digital Camera '], [' Printer', ' Lab Top'], [' Flash Drive', 'Digital Camera '], [' Flash Drive', ' Lab Top'], [' Microsoft Office', 'Lab Top'], [' Microsoft Office', 'Digital Camera '], [' Microsoft Office', ' Lab Top'], [' Speakers', 'Lab Top'], ['Lab Top', 'Digital Camera '], ['Lab Top', ' Lab Top'], [' External Hard-Drive', 'Digital Camera '], [' External Hard-Drive', ' Lab Top']]
#
# Table of selected Frequent itemsets L2
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive']   :   9
# [' Printer', ' Microsoft Office']   :   8
# [' Printer', ' Speakers']   :   4
# [' Printer', ' Lab Top Case']   :   5
# [' Printer', ' Anti-Virus']   :   6
# [' Printer', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office']   :   11
# [' Flash Drive', ' Speakers']   :   6
# [' Flash Drive', 'Lab Top']   :   5
# [' Flash Drive', ' Lab Top Case']   :   9
# [' Flash Drive', ' Anti-Virus']   :   10
# [' Flash Drive', ' External Hard-Drive']   :   6
# [' Microsoft Office', ' Speakers']   :   6
# [' Microsoft Office', ' Lab Top Case']   :   7
# [' Microsoft Office', ' Anti-Virus']   :   8
# [' Microsoft Office', ' External Hard-Drive']   :   5
# [' Speakers', ' Lab Top Case']   :   9
# [' Speakers', ' Anti-Virus']   :   9
# [' Speakers', ' External Hard-Drive']   :   6
# [' Speakers', 'Digital Camera ']   :   6
# [' Speakers', ' Lab Top']   :   4
# ['Lab Top', ' Lab Top Case']   :   5
# ['Lab Top', ' Anti-Virus']   :   6
# ['Lab Top', ' External Hard-Drive']   :   4
# [' Lab Top Case', ' Anti-Virus']   :   12
# [' Lab Top Case', ' External Hard-Drive']   :   8
# [' Lab Top Case', 'Digital Camera ']   :   6
# [' Lab Top Case', ' Lab Top']   :   5
# [' Anti-Virus', ' External Hard-Drive']   :   9
# [' Anti-Virus', 'Digital Camera ']   :   4
# [' Anti-Virus', ' Lab Top']   :   4
# ['Digital Camera ', ' Lab Top']   :   5
#
#
#
# {1: [['Desk Top'], [' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], [' Anti-Virus '], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive '], [' External Hard-Drive'], [' Lab Top Case '], [' Microsoft Office '], ['Digital Camera '], [' Lab Top'], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera
' External Hard-Drive', 'Digital Camera ']   :   2
# [' Speakers', ' External Hard-Drive', ' Lab Top']   :   2
# [' Speakers', 'Digital Camera ', ' Lab Top']   :   4
# ['Lab Top', ' Lab Top Case', ' Anti-Virus']   :   5
# ['Lab Top', ' Lab Top Case', ' External Hard-Drive']   :   3
# ['Lab Top', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   8
# [' Lab Top Case', ' Anti-Virus', 'Digital Camera ']   :   4
# [' Lab Top Case', ' Anti-Virus', ' Lab Top']   :   4
# [' Lab Top Case', ' External Hard-Drive', 'Digital Camera ']   :   2
# [' Lab Top Case', ' External Hard-Drive', ' Lab Top']   :   2
# [' Lab Top Case', 'Digital Camera ', ' Lab Top']   :   5
# [' Anti-Virus', ' External Hard-Drive', 'Digital Camera ']   :   2
# [' Anti-Virus', ' External Hard-Drive', ' Lab Top']   :   2
# [' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
#
#
#
# List of Frequent Items- [[' Printer', ' Flash Drive', ' Microsoft Office'], [' Printer', ' Flash Drive', ' Speakers'], [' Printer', ' Flash Drive', ' Lab Top Case'], [' Printer', ' Flash Drive', ' Anti-Virus'], [' Printer', ' Flash Drive', ' External Hard-Drive'], [' Printer', ' Microsoft Office', ' Speakers'], [' Printer', ' Microsoft Office', ' Lab Top Case'], [' Printer', ' Microsoft Office', ' Anti-Virus'], [' Printer', ' Speakers', ' Anti-Virus'], [' Printer', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Lab Top Case', ' External Hard-Drive'], [' Printer', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case'], [' Flash Drive', ' Microsoft Office', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' External Hard-Drive'], [' Flash Drive', ' Speakers', ' Lab Top Case'], [' Flash Drive', ' Speakers', ' Anti-Virus'], [' Flash Drive', ' Speakers', ' External Hard-Drive'], [' Flash Drive', 'Lab Top', ' Lab Top Case'], [' Flash Drive', 'Lab Top', ' Anti-Virus'], [' Flash Drive', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Lab Top Case'], [' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Microsoft Office', ' Speakers', ' External Hard-Drive'], [' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Microsoft Office', ' Lab Top Case', ' External Hard-Drive'], [' Microsoft Office', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' Lab Top'], [' Speakers', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Anti-Virus', 'Digital Camera '], [' Speakers', ' Anti-Virus', ' Lab Top'], [' Speakers', 'Digital Camera ', ' Lab Top'], ['Lab Top', ' Lab Top Case', ' Anti-Virus'], ['Lab Top', ' Anti-Virus', ' External Hard-Drive'], [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Lab Top Case', ' Anti-Virus', 'Digital Camera '], [' Lab Top Case', ' Anti-Virus', ' Lab Top'], [' Lab Top Case', 'Digital Camera ', ' Lab Top'], [' Anti-Virus', 'Digital Camera ', ' Lab Top']]
# Support Count- [8, 4, 5, 6, 4, 4, 4, 5, 4, 5, 4, 4, 6, 7, 8, 5, 5, 6, 4, 4, 4, 9, 6, 6, 5, 6, 4, 7, 5, 5, 8, 6, 5, 4, 6, 4, 4, 4, 5, 4, 8, 4, 4, 5, 4]
#  [[' Printer', ' Microsoft Office', ' External Hard-Drive'], [' Printer', ' Speakers', ' Lab Top Case'], [' Printer', ' Speakers', ' External Hard-Drive'], [' Flash Drive', 'Lab Top', ' External Hard-Drive'], ['Lab Top', ' Lab Top Case', ' External Hard-Drive']]
#
# Table of selected Frequent itemsets L3
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive', ' Microsoft Office']   :   8
# [' Printer', ' Flash Drive', ' Speakers']   :   4
# [' Printer', ' Flash Drive', ' Lab Top Case']   :   5
# [' Printer', ' Flash Drive', ' Anti-Virus']   :   6
# [' Printer', ' Flash Drive', ' External Hard-Drive']   :   4
# [' Printer', ' Microsoft Office', ' Speakers']   :   4
# [' Printer', ' Microsoft Office', ' Lab Top Case']   :   4
# [' Printer', ' Microsoft Office', ' Anti-Virus']   :   5
# [' Printer', ' Speakers', ' Anti-Virus']   :   4
# [' Printer', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Printer', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Printer', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers']   :   6
# [' Flash Drive', ' Microsoft Office', ' Lab Top Case']   :   7
# [' Flash Drive', ' Microsoft Office', ' Anti-Virus']   :   8
# [' Flash Drive', ' Microsoft Office', ' External Hard-Drive']   :   5
# [' Flash Drive', ' Speakers', ' Lab Top Case']   :   5
# [' Flash Drive', ' Speakers', ' Anti-Virus']   :   6
# [' Flash Drive', ' Speakers', ' External Hard-Drive']   :   4
# [' Flash Drive', 'Lab Top', ' Lab Top Case']   :   4
# [' Flash Drive', 'Lab Top', ' Anti-Virus']   :   4
# [' Flash Drive', ' Lab Top Case', ' Anti-Virus']   :   9
# [' Flash Drive', ' Lab Top Case', ' External Hard-Drive']   :   6
# [' Flash Drive', ' Anti-Virus', ' External Hard-Drive']   :   6
# ['
' External Hard-Drive', 'Digital Camera ']   :   2
# [' Speakers', ' Anti-Virus', ' External Hard-Drive', ' Lab Top']   :   2
# [' Speakers', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
# [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', 'Digital Camera ']   :   2
# [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Lab Top']   :   2
# [' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
#
#
#
# List of Frequent Items- [[' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers'], [' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case'], [' Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus'], [' Printer', ' Flash Drive', ' Speakers', ' Anti-Virus'], [' Printer', ' Flash Drive', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Flash Drive', ' Lab Top Case', ' External Hard-Drive'], [' Printer', ' Flash Drive', ' Anti-Virus', ' External Hard-Drive'], [' Printer', ' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Printer', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Speakers', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', 'Lab Top', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Microsoft Office', ' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' Anti-Virus', ' Lab Top'], [' Speakers', ' Lab Top Case', 'Digital Camera ', ' Lab Top'], [' Speakers', ' Anti-Virus', 'Digital Camera ', ' Lab Top'], [' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']]
# Support Count- [4, 4, 5, 4, 5, 4, 4, 4, 4, 4, 5, 6, 4, 7, 5, 5, 5, 4, 4, 4, 6, 5, 4, 4, 5, 6, 4, 4, 4, 4, 4]
#  [[' Speakers', ' Lab Top Case', ' External Hard-Drive', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' External Hard-Drive', ' Lab Top'], [' Speakers', ' Anti-Virus', ' External Hard-Drive', 'Digital Camera '], [' Speakers', ' Anti-Virus', ' External Hard-Drive', ' Lab Top'], [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', 'Digital Camera '], [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Lab Top']]
#
# Table of selected Frequent itemsets L4
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers']   :   4
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case']   :   4
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Anti-Virus']   :   5
# [' Printer', ' Flash Drive', ' Speakers', ' Anti-Virus']   :   4
# [' Printer', ' Flash Drive', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Printer', ' Flash Drive', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Printer', ' Flash Drive', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Printer', ' Microsoft Office', ' Speakers', ' Anti-Virus']   :   4
# [' Printer', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']   :   4
# [' Printer', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case']   :   5
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus']   :   6
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']   :   7
# [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' External Hard-Drive']   :   5
# [' Flash Drive', ' Microsoft Office', ' Anti-Virus', ' External Hard-Drive']   :   5
# [' Flash Drive', ' Speakers', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Flash Drive', ' Speakers', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Speakers', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', 'Lab Top', ' Lab Top Case', ' Anti-Virus']   :   4
# [' Flash Drive', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   6
# [' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Microsoft Office', ' Speakers', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Microsoft Office', ' Speakers', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   5
# [' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   6
# [' Speakers', ' Lab Top Case', ' Anti-Virus', 'Digital Camera ']   :   4
# [' Speakers', ' Lab Top Case', ' Anti-Virus', ' Lab Top']   :   4
# [' Speakers', ' Lab Top Case', 'Digital Camera ', ' Lab Top']   :   4
# [' Speakers', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
# [' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
#
#
#
# {1: [['Desk Top'], [' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], [' Anti-Virus '], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive '], [' External Hard-Drive'], [' Lab Top Case '], [' Microsoft Office '], ['Digital Camera '], [' Lab Top'], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera']], 2: [[' Printer', ' Flash Drive'], [' Printer', ' Microsoft Office'], [' Printer', ' Speakers'], [' Printer', 'Lab Top'], [' Printer', ' Lab Top Case'], [' Printer', ' Anti-Virus'], [' Printer', ' External Hard-Drive'], [' Printer', 'Digital Camera '], [' Printer', ' Lab Top'], [' Flash Drive', ' Microsoft Office'], [' Flash Drive', ' Speakers'], [' Flash Drive', 'Lab Top'], [' Flash Drive', ' Lab Top Case'], [' Flash Drive', ' Anti-Virus'], [' Flash Drive', ' External Hard-Drive'], [' Flash Drive', 'Digital Camera '], [' Flash Drive', ' Lab Top'], [' Microsoft Office', ' Speakers'], [' Microsoft Office', 'Lab Top'], [' Microsoft Office', ' Lab Top Case'], [' Microsoft Office', ' Anti-Virus'], [' Microsoft Office', ' External Hard-Drive'], [' Microsoft Office', 'Digital Camera '], [' Microsoft Office', ' Lab Top'], [' Speakers', 'Lab Top'], [' Speakers', ' Lab Top Case'], [' Speakers', ' Anti-Virus'], [' Speakers', ' External Hard-Drive'], [' Speakers', 'Digital Camera '], [' Speakers', ' Lab Top'], ['Lab Top', ' Lab Top Case'], ['Lab Top', ' Anti-Virus'], ['Lab Top', ' External Hard-Drive'], ['Lab Top', 'Digital Camera '], ['Lab Top', ' Lab Top'], [' Lab Top Case', ' Anti-Virus'], [' Lab Top Case', ' External Hard-Drive'], [' Lab Top Case', 'Digital Camera '], [' Lab Top Case', ' Lab Top'], [' Anti-Virus', ' External Hard-Drive'], [' Anti-Virus', 'Digital Camera '], [' Anti-Virus', ' Lab Top'], [' External Hard-Drive', 'Digital Camera '], [' External Hard-Drive', ' Lab Top'], ['Digital Camera ', ' Lab Top']], 3: [[' Printer', ' Flash Drive', ' Microsoft Office'], [' Printer', ' Flash Drive', ' Speakers'], [' Printer', ' Flash Drive', ' Lab Top Case'], [' Printer', ' Flash Drive', ' Anti-Virus'], [' Printer', ' Flash Drive', ' External Hard-Drive'], [' Printer', ' Microsoft Office', ' Speakers'], [' Printer', ' Microsoft Office', ' Lab Top Case'], [' Printer', ' Microsoft Office', ' Anti-Virus'], [' Printer', ' Microsoft Office', ' External Hard-Drive'], [' Printer', ' Speakers', ' Lab Top Case'], [' Printer', ' Speakers', ' Anti-Virus'], [' Printer', ' Speakers', ' External Hard-Drive'], [' Printer', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Lab Top Case', ' External Hard-Drive'], [' Printer', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers'], [' Flash Drive', ' Microsoft Office', 'Lab Top'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case'], [' Flash Drive', ' Microsoft Office', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' External Hard-Drive'], [' Flash Drive', ' Speakers', 'Lab Top'], [' Flash Drive', ' Speakers', ' Lab Top Case'], [' Flash Drive', ' Speakers', ' Anti-Virus'], [' Flash Drive', ' Speakers', ' External Hard-Drive'], [' Flash Drive', 'Lab Top', ' Lab Top Case'], [' Flash Drive', 'Lab Top', ' Anti-Virus'], [' Flash Drive', 'Lab Top', ' External Hard-Drive'], [' Flash Drive', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Lab Top Case'], [' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Microsoft Office', ' Speakers', ' External Hard-Drive'], [' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Microsoft Office', ' Lab Top Case', ' External Hard-Drive'], [' Microsoft Office', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' Lab Top'], [' Speakers', ' Anti-Virus', ' External Hard-Drive ...
#
# Table of Frequent itemsets C5:
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case']   :   3
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus']   :   4
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']   :   4
# [' Printer', ' Flash Drive', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   5
# [' Flash Drive', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', 'Digital Camera ']   :   2
# [' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Lab Top']   :   2
# [' Speakers', ' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
#
#
#
# List of Frequent Items- [[' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Flash Drive', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']]
# Support Count- [4, 4, 4, 5, 4, 4, 5, 4, 4, 4]
#  [[' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case']]
#
# Table of selected Frequent itemsets L5
#
# Itemset  | Frequency
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus']   :   4
# [' Printer', ' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus']   :   4
# [' Printer', ' Flash Drive', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus']   :   5
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Flash Drive', ' Microsoft Office', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   5
# [' Flash Drive', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
# [' Speakers', ' Lab Top Case', ' Anti-Virus', 'Digital Camera ', ' Lab Top']   :   4
#
#
#
# {1: [['Desk Top'], [' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], [' Anti-Virus '], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive '], [' External Hard-Drive'], [' Lab Top Case '], [' Microsoft Office '], ['Digital Camera '], [' Lab Top'], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera']], 2: [[' Printer', ' Flash Drive'], [' Printer', ' Microsoft Office'], [' Printer', ' Speakers'], [' Printer', 'Lab Top'], [' Printer', ' Lab Top Case'], [' Printer', ' Anti-Virus'], [' Printer', ' External Hard-Drive'], [' Printer', 'Digital Camera '], [' Printer', ' Lab Top'], [' Flash Drive', ' Microsoft Office'], [' Flash Drive', ' Speakers'], [' Flash Drive', 'Lab Top'], [' Flash Drive', ' Lab Top Case'], [' Flash Drive', ' Anti-Virus'], [' Flash Drive', ' External Hard-Drive'], [' Flash Drive', 'Digital Camera '], [' Flash Drive', ' Lab Top'], [' Microsoft Office', ' Speakers'], [' Microsoft Office', 'Lab Top'], [' Microsoft Office', ' Lab Top Case'], [' Microsoft Office', ' Anti-Virus'], [' Microsoft Office', ' External Hard-Drive'], [' Microsoft Office', 'Digital Camera '], [' Microsoft Office', ' Lab Top'], [' Speakers', 'Lab Top'], [' Speakers', ' Lab Top Case'], [' Speakers', ' Anti-Virus'], [' Speakers', ' External Hard-Drive'], [' Speakers', 'Digital Camera '], [' Speakers', ' Lab Top'], ['Lab Top', ' Lab Top Case'], ['Lab Top', ' Anti-Virus'], ['Lab Top', ' External Hard-Drive'], ['Lab Top', 'Digital Camera '], ['Lab Top', ' Lab Top'], [' Lab Top Case', ' Anti-Virus'], [' Lab Top Case', ' External Hard-Drive'], [' Lab Top Case', 'Digital Camera '], [' Lab Top Case', ' Lab Top'], [' Anti-Virus', ' External Hard-Drive'], [' Anti-Virus', 'Digital Camera '], [' Anti-Virus', ' Lab Top'], [' External Hard-Drive', 'Digital Camera '], [' External Hard-Drive', ' Lab Top'], ['Digital Camera ', ' Lab Top']], 3: [[' Printer', ' Flash Drive', ' Microsoft Office'], [' Printer', ' Flash Drive', ' Speakers'], [' Printer', ' Flash Drive', ' Lab Top Case'], [' Printer', ' Flash Drive', ' Anti-Virus'], [' Printer', ' Flash Drive', ' External Hard-Drive'], [' Printer', ' Microsoft Office', ' Speakers'], [' Printer', ' Microsoft Office', ' Lab Top Case'], [' Printer', ' Microsoft Office', ' Anti-Virus'], [' Printer', ' Microsoft Office', ' External Hard-Drive'], [' Printer', ' Speakers', ' Lab Top Case'], [' Printer', ' Speakers', ' Anti-Virus'], [' Printer', ' Speakers', ' External Hard-Drive'], [' Printer', ' Lab Top Case', ' Anti-Virus'], [' Printer', ' Lab Top Case', ' External Hard-Drive'], [' Printer', ' Anti-Virus', ' External Hard-Drive'], [' Flash Drive', ' Microsoft Office', ' Speakers'], [' Flash Drive', ' Microsoft Office', 'Lab Top'], [' Flash Drive', ' Microsoft Office', ' Lab Top Case'], [' Flash Drive', ' Microsoft Office', ' Anti-Virus'], [' Flash Drive', ' Microsoft Office', ' External Hard-Drive'], [' Flash Drive', ' Speakers', 'Lab Top'], [' Flash Drive', ' Speakers', ' Lab Top Case'], [' Flash Drive', ' Speakers', ' Anti-Virus'], [' Flash Drive', ' Speakers', ' External Hard-Drive'], [' Flash Drive', 'Lab Top', ' Lab Top Case'], [' Flash Drive', 'Lab Top', ' Anti-Virus'], [' Flash Drive', 'Lab Top', ' External Hard-Drive'], [' Flash Drive', ' Lab Top Case', ' Anti-Virus'], [' Flash Drive', ' Lab Top Case', ' External Hard-Drive'], [' Flash Drive', ' Anti-Virus', ' External Hard-Drive'], [' Microsoft Office', ' Speakers', ' Lab Top Case'], [' Microsoft Office', ' Speakers', ' Anti-Virus'], [' Microsoft Office', ' Speakers', ' External Hard-Drive'], [' Microsoft Office', ' Lab Top Case', ' Anti-Virus'], [' Microsoft Office', ' Lab Top Case', ' External Hard-Drive'], [' Microsoft Office', ' Anti-Virus', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' Lab Top'], [' Speakers', ' Anti-Virus', ' External Hard-Drive ...
#
# Table of Frequent itemsets C6:
#
# Itemset  | Frequency
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
#
#
#
# List of Frequent Items- [[' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']]
# Support Count- [4]
#  []
#
# Table of selected Frequent itemsets L6
#
# Itemset  | Frequency
# [' Flash Drive', ' Microsoft Office', ' Speakers', ' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']   :   4
#
#
#
# {1: [['Desk Top'], [' Printer'], [' Flash Drive'], [' Microsoft Office'], [' Speakers'], [' Anti-Virus '], ['Lab Top'], [' Lab Top Case'], [' Anti-Virus'], [' External Hard-Drive '], [' External Hard-Drive'], [' Lab Top Case '], [' Microsoft Office '], ['Digital Camera '], [' Lab Top'], [' Desk Top'], [' Speakers '], ['Printer'], ['Digital Camera']], 2: [[' Printer', ' Flash Drive'], [' Printer', ' Microsoft Office'], [' Printer', ' Speakers'], [' Printer', 'Lab Top'], [' Printer', ' Lab Top Case'], [' Printer', ' Anti-Virus'], [' Printer', ' External Hard-Drive'], [' Printer', 'Digital Camera '], [' Printer', ' Lab Top'], [' Flash Drive', ' Microsoft Office'], [' Flash Drive', ' Speakers'], [' Flash Drive', 'Lab Top'], [' Flash Drive', ' Lab Top Case'], [' Flash Drive', ' Anti-Virus'], [' Flash Drive', ' External Hard-Drive'], [' Flash Drive', 'Digital Camera '], [' Flash Drive', ' Lab Top'], [' Microsoft Office', ' Speakers'], [' Microsoft Office', 'Lab Top'], [' Microsoft Office', ' Lab Top Case'], [' Microsoft Office', ' Anti-Virus'], [' Microsoft Office', ' External Hard-Drive'], [' Microsoft Office', 'Digital Camera '], [' Microsoft Office', ' Lab Top'], [' Speakers', 'Lab Top'], [' Speakers', ' Lab Top Case'], [' Speakers', '
' External Hard-Drive'], [' Speakers', ' Lab Top Case', ' Anti-Virus'], [' Speakers', ' Lab Top Case', ' External Hard-Drive'], [' Speakers', ' Lab Top Case', 'Digital Camera '], [' Speakers', ' Lab Top Case', ' Lab Top'], [' Speakers', ' Anti-Virus', ' External Hard-Drive ...
#
# Table of Frequent itemsets C7:
#
# Itemset  | Frequency
#
#
#
# List of Frequent Items- []
# Support Count- []
#  []

# %%
#generate association rules
#we need to loop over all the frequent itemsets i.e the itemsets in L
#for each itemsets we need to generate all the rules according to the combinations
#frequent itemsets of size 1 cannot producce significant rules so we can start with size 2 i.e K=1 in dictionary 
assoc_rules_str=""
for i in range(1, len(L)):
    for j in range(len(L[i])):
        s = powerset(L[i][j]) #to produce combinations
        s.pop()#get rid of last element which contains subsets of all the items and we dont need that
        for z in s:
            S = set(z)
            X = set(L[i][j])
            X_S=set(X-S)
            sup_x = occurence_count(X,Transactions)
            sup_x_s =occurence_count(X_S,Transactions)
            conf = sup_x/occurence_count(S,Transactions)
            if conf>= min_conf  and sup_x>= min_support:
                assoc_rules_str+= write_rules(X,X_S,S,conf,sup_x,number_of_trans)

# %%
print(assoc_rules_str)
# Out:
# Freq. Itemsets: {' Printer', ' Flash Drive'}
#     Rule: [' Printer'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.450
# Freq. Itemsets: {' Printer', ' Flash Drive'}
#     Rule: [' Flash Drive'] -> [' Printer']
#    Confidance: 0.692    Support: 0.450
# Freq. Itemsets: {' Printer', ' Microsoft Office'}
#     Rule: [' Printer'] -> [' Microsoft Office']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Printer', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Printer']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Printer', ' Speakers'}
#     Rule: [' Printer'] -> [' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers'}
#     Rule: [' Speakers'] -> [' Printer']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case'}
#     Rule: [' Printer'] -> [' Lab Top Case']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case'}
#     Rule: [' Lab Top Case'] -> [' Printer']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus'}
#     Rule: [' Printer'] -> [' Anti-Virus']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Printer', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Printer']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Printer', ' External Hard-Drive'}
#     Rule: [' Printer'] -> [' External Hard-Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Printer']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive'] -> [' Microsoft Office']
#    Confidance: 0.846    Support: 0.550
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.550
# Freq. Itemsets: {' Flash Drive', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Speakers']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' Flash Drive']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Flash Drive', 'Lab Top'}
#     Rule: [' Flash Drive'] -> ['Lab Top']
#    Confidance: 0.385    Support: 0.250
# Freq. Itemsets: {' Flash Drive', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Flash Drive']
#    Confidance: 0.714    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case']
#    Confidance: 0.692    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive'}
#     Rule: [' Lab Top Case'] -> [' Flash Drive']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus'}
#     Rule: [' Flash Drive'] -> [' Anti-Virus']
#    Confidance: 0.769    Support: 0.500
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Flash Drive']
#    Confidance: 0.714    Support: 0.500
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Flash Drive'] -> [' External Hard-Drive']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Flash Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Microsoft Office'}
#     Rule: [' Speakers'] -> [' Microsoft Office']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 0.636    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Lab Top Case'] -> [' Microsoft Office']
#    Confidance: 0.500    Support: 0.350
# Freq. Itemsets: {' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' Microsoft Office']
#    Confidance: 0.571    Support: 0.400
# Freq. Itemsets: {' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' External Hard-Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive'] -> [' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers'}
#     Rule: [' Speakers'] -> [' Lab Top Case']
#    Confidance: 0.818    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Speakers'}
#     Rule: [' Lab Top Case'] -> [' Speakers']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' Anti-Virus', ' Speakers'}
#     Rule: [' Speakers'] -> [' Anti-Virus']
#    Confidance: 0.818    Support: 0.450
# Freq. Itemsets: {' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus'] -> [' Speakers']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' External Hard-Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' External Hard-Drive']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Speakers'}
#     Rule: [' External Hard-Drive'] -> [' Speakers']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Speakers', 'Digital Camera '}
#     Rule: [' Speakers'] -> ['Digital Camera ']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Speakers', 'Digital Camera '}
#     Rule: ['Digital Camera '] -> [' Speakers']
#    Confidance: 0.750    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Lab Top'}
#     Rule: [' Speakers'] -> [' Lab Top']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Speakers', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Lab Top Case']
#    Confidance: 0.714    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', 'Lab Top'}
#     Rule: [' Lab Top Case'] -> ['Lab Top']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Anti-Virus', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Anti-Virus']
#    Confidance: 0.857    Support: 0.300
# Freq. Itemsets: {' Anti-Virus', 'Lab Top'}
#     Rule: [' Anti-Virus'] -> ['Lab Top']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' External Hard-Drive']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', 'Lab Top'}
#     Rule: [' External Hard-Drive'] -> ['Lab Top']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Lab Top Case'] -> [' Anti-Virus']
#    Confidance: 0.857    Support: 0.600
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Lab Top Case']
#    Confidance: 0.857    Support: 0.600
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' Lab Top Case'] -> [' External Hard-Drive']
#    Confidance: 0.571    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Lab Top Case']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', 'Digital Camera '}
#     Rule: [' Lab Top Case'] -> ['Digital Camera ']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', 'Digital Camera '}
#     Rule: ['Digital Camera '] -> [' Lab Top Case']
#    Confidance: 0.750    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Lab Top'}
#     Rule: [' Lab Top Case'] -> [' Lab Top']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Anti-Virus'] -> [' External Hard-Drive']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.450
# Freq. Itemsets: {' Anti-Virus', 'Digital Camera '}
#     Rule: ['Digital Camera '] -> [' Anti-Virus']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Anti-Virus']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {'Digital Camera ', ' Lab Top'}
#     Rule: ['Digital Camera '] -> [' Lab Top']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {'Digital Camera ', ' Lab Top'}
#     Rule: [' Lab Top'] -> ['Digital Camera ']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Printer'] -> [' Flash Drive', ' Microsoft Office']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive'] -> [' Printer', ' Microsoft Office']
#    Confidance: 0.615    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Printer', ' Flash Drive']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Printer', ' Flash Drive'] -> [' Microsoft Office']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Printer', ' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' Printer']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Printer'] -> [' Flash Drive', ' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Printer', ' Speakers']
#    Confidance: 0.308    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' Printer', ' Flash Drive']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Printer', ' Flash Drive'] -> [' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Printer', ' Speakers'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' Printer']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Printer'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Flash Drive'] -> [' Printer', ' Lab Top Case']
#    Confidance: 0.385    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Lab Top Case'] -> [' Printer', ' Flash Drive']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Printer', ' Flash Drive'] -> [' Lab Top Case']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Printer', ' Lab Top Case'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Lab Top Case'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' Printer']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Printer'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Flash Drive'] -> [' Printer', ' Anti-Virus']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Printer', ' Flash Drive']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Printer', ' Flash Drive'] -> [' Anti-Virus']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Printer', ' Anti-Virus'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' Printer']
#    Confidance: 0.600    Support: 0.300
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Printer'] -> [' Flash Drive', ' External Hard-Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Flash Drive'] -> [' Printer', ' External Hard-Drive']
#    Confidance: 0.308    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Printer', ' Flash Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Printer', ' Flash Drive'] -> [' External Hard-Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Printer', ' External Hard-Drive'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Printer']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Printer'] -> [' Speakers', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Printer', ' Speakers']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Speakers'] -> [' Printer', ' Microsoft Office']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Printer', ' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Printer', ' Speakers'] -> [' Microsoft Office']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Speakers', ' Microsoft Office'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' Printer']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Printer'] -> [' Lab Top Case', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Printer', ' Lab Top Case']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Printer', ' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Printer', ' Lab Top Case'] -> [' Microsoft Office']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' Printer']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Printer'] -> [' Anti-Virus', ' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Printer', ' Anti-Virus']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' Printer', ' Microsoft Office']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Printer', ' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Printer', ' Anti-Virus'] -> [' Microsoft Office']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' Printer']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Speakers'}
#     Rule: [' Printer'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Speakers'}
#     Rule: [' Speakers'] -> [' Printer', ' Anti-Virus']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Speakers'}
#     Rule: [' Printer', ' Speakers'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Speakers'}
#     Rule: [' Printer', ' Anti-Virus'] -> [' Speakers']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Printer']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Printer'] -> [' Lab Top Case', ' Anti-Virus']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Lab Top Case'] -> [' Printer', ' Anti-Virus']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Printer', ' Lab Top Case']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Printer', ' Lab Top Case'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Printer', ' Anti-Virus'] -> [' Lab Top Case']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' Anti-Virus'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> [' Printer']
#    Confidance: 0.417    Support: 0.250
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' Printer'] -> [' Lab Top Case', ' External Hard-Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Printer', ' Lab Top Case']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' Printer', ' Lab Top Case'] -> [' External Hard-Drive']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' Printer', ' External Hard-Drive'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Lab Top Case', ' External Hard-Drive'}
#     Rule: [' Lab Top Case', ' External Hard-Drive'] -> [' Printer']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Printer'] -> [' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Printer', ' Anti-Virus']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Printer', ' Anti-Virus'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Printer', ' External Hard-Drive'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Printer', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Anti-Virus', ' External Hard-Drive'] -> [' Printer']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Speakers', ' Microsoft Office']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Microsoft Office'] -> [' Flash Drive', ' Speakers']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Speakers'] -> [' Flash Drive', ' Microsoft Office']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' Microsoft Office']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Microsoft Office', ' Speakers'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case', ' Microsoft Office']
#    Confidance: 0.538    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.636    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case'] -> [' Flash Drive', ' Microsoft Office']
#    Confidance: 0.500    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 0.636    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' Microsoft Office']
#    Confidance: 0.778    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.350
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Flash Drive'] -> [' Anti-Virus', ' Microsoft Office']
#    Confidance: 0.615    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' Flash Drive', ' Microsoft Office']
#    Confidance: 0.571    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' Microsoft Office']
#    Confidance: 0.800    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.400
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive'] -> [' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.385    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Flash Drive', ' External Hard-Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive'] -> [' Flash Drive', ' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' External Hard-Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Microsoft Office']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive', ' Microsoft Office'] -> [' Flash Drive']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.385    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Lab Top Case'] -> [' Flash Drive', ' Speakers']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' Lab Top Case']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' Speakers']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Speakers'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' Flash Drive']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Speakers'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus'] -> [' Flash Drive', ' Speakers']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' Speakers']
#    Confidance: 0.600    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Flash Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Flash Drive'] -> [' Speakers', ' External Hard-Drive']
#    Confidance: 0.308    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' Flash Drive', ' External Hard-Drive']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' External Hard-Drive'] -> [' Flash Drive', ' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Speakers']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' External Hard-Drive', ' Speakers'}
#     Rule: [' External Hard-Drive', ' Speakers'] -> [' Flash Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', 'Lab Top'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case', 'Lab Top']
#    Confidance: 0.308    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', 'Lab Top'}
#     Rule: [' Flash Drive', 'Lab Top'] -> [' Lab Top Case']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', 'Lab Top'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> ['Lab Top']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', 'Lab Top'}
#     Rule: [' Lab Top Case', 'Lab Top'] -> [' Flash Drive']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Flash Drive'] -> [' Anti-Virus', 'Lab Top']
#    Confidance: 0.308    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Flash Drive', 'Lab Top'] -> [' Anti-Virus']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> ['Lab Top']
#    Confidance: 0.400    Support: 0.200
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Anti-Virus', 'Lab Top'] -> [' Flash Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case', ' Anti-Virus']
#    Confidance: 0.692    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Lab Top Case'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Anti-Virus'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.643    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' Lab Top Case']
#    Confidance: 0.900    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' Anti-Virus'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> [' Flash Drive']
#    Confidance: 0.750    Support: 0.450
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Flash Drive'] -> [' Lab Top Case', ' External Hard-Drive']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Lab Top Case'] -> [' Flash Drive', ' External Hard-Drive']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Lab Top Case', ' Flash Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Flash Drive', ' External Hard-Drive'}
#     Rule: [' Lab Top Case', ' External Hard-Drive'] -> [' Flash Drive']
#    Confidance: 0.750    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Flash Drive'] -> [' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.462    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Anti-Virus'] -> [' Flash Drive', ' External Hard-Drive']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' External Hard-Drive'] -> [' Flash Drive', ' Anti-Virus']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' External Hard-Drive']
#    Confidance: 0.600    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Flash Drive', ' Anti-Virus', ' External Hard-Drive'}
#     Rule: [' Anti-Virus', ' External Hard-Drive'] -> [' Flash Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Speakers'] -> [' Lab Top Case', ' Microsoft Office']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Lab Top Case'] -> [' Speakers', ' Microsoft Office']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.714    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Speakers'] -> [' Anti-Virus', ' Microsoft Office']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' Speakers', ' Microsoft Office']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.750    Support: 0.300
# Freq. Itemsets: {' Speakers', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Microsoft Office']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' External Hard-Drive', ' Speakers']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Speakers'] -> [' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive'] -> [' Speakers', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive', ' Microsoft Office'] -> [' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Speakers', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive', ' Speakers'] -> [' Microsoft Office']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Lab Top Case', ' Anti-Virus']
#    Confidance: 0.636    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Lab Top Case'] -> [' Anti-Virus', ' Microsoft Office']
#    Confidance: 0.500    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' Lab Top Case', ' Microsoft Office']
#    Confidance: 0.500    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 0.875    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> [' Microsoft Office']
#    Confidance: 0.583    Support: 0.350
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Lab Top Case', ' External Hard-Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case'] -> [' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive'] -> [' Lab Top Case', ' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' External Hard-Drive']
#    Confidance: 0.714    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' External Hard-Drive', ' Microsoft Office'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Microsoft Office'}
#     Rule: [' Lab Top Case', ' External Hard-Drive'] -> [' Microsoft Office']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Microsoft Office'] -> [' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus'] -> [' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' External Hard-Drive'] -> [' Anti-Virus', ' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' External Hard-Drive']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' External Hard-Drive', ' Microsoft Office'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Microsoft Office'}
#     Rule: [' Anti-Virus', ' External Hard-Drive'] -> [' Microsoft Office']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Speakers'] -> [' Lab Top Case', ' Anti-Virus']
#    Confidance: 0.727    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Lab Top Case'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.571    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus'] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.571    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' Anti-Virus']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Lab Top Case']
#    Confidance: 0.889    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', ' Speakers'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> [' Speakers']
#    Confidance: 0.667    Support: 0.400
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Speakers'] -> [' Lab Top Case', ' External Hard-Drive']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Lab Top Case'] -> [' Speakers', ' External Hard-Drive']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' External Hard-Drive'] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' External Hard-Drive', ' Speakers'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' External Hard-Drive', ' Speakers'}
#     Rule: [' Lab Top Case', ' External Hard-Drive'] -> [' Speakers']
#    Confidance: 0.750    Support: 0.300
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: [' Speakers'] -> [' Lab Top Case', 'Digital Camera ']
#    Confidance: 0.455    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: [' Lab Top Case'] -> [' Speakers', 'Digital Camera ']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: ['Digital Camera '] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.625    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: [' Lab Top Case', ' Speakers'] -> ['Digital Camera ']
#    Confidance: 0.556    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: [' Speakers', 'Digital Camera '] -> [' Lab Top Case']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', 'Digital Camera '}
#     Rule: [' Lab Top Case', 'Digital Camera '] -> [' Speakers']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Lab Top'}
#     Rule: [' Speakers'] -> [' Lab Top Case', ' Lab Top']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Lab Top Case', ' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Lab Top'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' Lab Top']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Lab Top'}
#     Rule: [' Speakers', ' Lab Top'] -> [' Lab Top Case']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Speakers', ' Lab Top'}
#     Rule: [' Lab Top Case', ' Lab Top'] -> [' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Speakers'] -> [' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.545    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus'] -> [' Speakers', ' External Hard-Drive']
#    Confidance: 0.429    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' External Hard-Drive'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' External Hard-Drive', ' Speakers'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.300
# Freq. Itemsets: {' External Hard-Drive', ' Anti-Virus', ' Speakers'}
#     Rule: [' Anti-Virus', ' External Hard-Drive'] -> [' Speakers']
#    Confidance: 0.667    Support: 0.300
# Freq. Itemsets: {' Anti-Virus', ' Speakers', 'Digital Camera '}
#     Rule: [' Speakers'] -> [' Anti-Virus', 'Digital Camera ']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', 'Digital Camera '}
#     Rule: ['Digital Camera '] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', 'Digital Camera '}
#     Rule: [' Anti-Virus', ' Speakers'] -> ['Digital Camera ']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', 'Digital Camera '}
#     Rule: [' Speakers', 'Digital Camera '] -> [' Anti-Virus']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', 'Digital Camera '}
#     Rule: [' Anti-Virus', 'Digital Camera '] -> [' Speakers']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', ' Lab Top'}
#     Rule: [' Speakers'] -> [' Anti-Virus', ' Lab Top']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Anti-Virus', ' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', ' Lab Top'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Lab Top']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', ' Lab Top'}
#     Rule: [' Speakers', ' Lab Top'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' Speakers', ' Lab Top'}
#     Rule: [' Anti-Virus', ' Lab Top'] -> [' Speakers']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: [' Speakers'] -> ['Digital Camera ', ' Lab Top']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: ['Digital Camera '] -> [' Speakers', ' Lab Top']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: [' Lab Top'] -> [' Speakers', 'Digital Camera ']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: [' Speakers', 'Digital Camera '] -> [' Lab Top']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: [' Speakers', ' Lab Top'] -> ['Digital Camera ']
#    Confidance: 1.000    Support: 0.200
# Freq. Itemsets: {' Speakers', 'Digital Camera ', ' Lab Top'}
#     Rule: ['Digital Camera ', ' Lab Top'] -> [' Speakers']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Lab Top Case', ' Anti-Virus']
#    Confidance: 0.714    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Lab Top Case'] -> [' Anti-Virus', 'Lab Top']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Anti-Virus'] -> [' Lab Top Case', 'Lab Top']
#    Confidance: 0.357    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Lab Top Case', 'Lab Top'] -> [' Anti-Virus']
#    Confidance: 1.000    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Anti-Virus', 'Lab Top'] -> [' Lab Top Case']
#    Confidance: 0.833    Support: 0.250
# Freq. Itemsets: {' Lab Top Case', ' Anti-Virus', 'Lab Top'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> ['Lab Top']
#    Confidance: 0.417    Support: 0.250
# Freq. Itemsets: {' Anti-Virus', ' External Hard-Drive', 'Lab Top'}
#     Rule: ['Lab Top'] -> [' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' External Hard-Drive', 'Lab Top'}
#     Rule: [' External Hard-Drive'] -> [' Anti-Virus', 'Lab Top']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' Anti-Virus', ' External Hard-Drive', 'Lab Top'}
#     Rule: [' Anti-Virus', 'Lab Top'] -> [' External Hard-Drive']
#    Confidance: 0.667    Support: 0.200
# ...
#     Rule: [' Flash Drive', ' Microsoft Office'] -> [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Speakers']
#    Confidance: 0.364    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Speakers'] -> [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' Flash Drive'] -> [' Speakers', ' Anti-Virus', ' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Anti-Virus'] -> [' Lab Top Case', ' External Hard-Drive', ' Speakers', ' Microsoft Office']
#    Confidance: 0.400    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' External Hard-Drive'] -> [' Lab Top Case', ' Anti-Virus', ' Microsoft Office', ' Speakers']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Speakers', ' Microsoft Office'] -> [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive', ' Flash Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' Microsoft Office'] -> [' Flash Drive', ' Anti-Virus', ' External Hard-Drive', ' Speakers']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Anti-Virus', ' Microsoft Office'] -> [' Lab Top Case', ' External Hard-Drive', ' Flash Drive', ' Speakers']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' External Hard-Drive', ' Microsoft Office'] -> [' Lab Top Case', ' Anti-Virus', ' Speakers', ' Flash Drive']
#    Confidance: 0.800    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' Speakers'] -> [' Flash Drive', ' Anti-Virus', ' External Hard-Drive', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Anti-Virus', ' Speakers'] -> [' Lab Top Case', ' External Hard-Drive', ' Flash Drive', ' Microsoft Office']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' External Hard-Drive', ' Speakers'] -> [' Lab Top Case', ' Anti-Virus', ' Microsoft Office', ' Flash Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' Anti-Virus'] -> [' Flash Drive', ' External Hard-Drive', ' Speakers', ' Microsoft Office']
#    Confidance: 0.333    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' External Hard-Drive'] -> [' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Anti-Virus', ' External Hard-Drive'] -> [' Lab Top Case', ' Microsoft Office', ' Flash Drive', ' Speakers']
#    Confidance: 0.444    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Microsoft Office', ' Speakers'] -> [' Lab Top Case', ' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.667    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Lab Top Case', ' Flash Drive', ' Microsoft Office'] -> [' Speakers', ' Anti-Virus', ' External Hard-Drive']
#    Confidance: 0.571    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', ' Anti-Virus', ' Microsoft Office'] -> [' Lab Top Case', ' External Hard-Drive', ' Speakers']
#    Confidance: 0.500    Support: 0.200
# Freq. Itemsets: {' External Hard-Drive', ' Lab Top Case', ' Flash Drive', ' Anti-Virus', ' Microsoft Office', ' Speakers'}
#     Rule: [' Flash Drive', 